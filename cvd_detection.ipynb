# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryamahatme/Data_sci_repo/blob/cvd_detection/cvd_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Course-End Project: Healthcare
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
data=pd.read_excel('/content/healthcare dataset.xlsx')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %% [markdown]
# Here, only oldpeak is float other columns are integers, overall the data is numeric.

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# as we can see here , no null values can be seen.

# %%
data.fbs.value_counts()
# Out:
# 0    258
# 1     45
# Name: fbs, dtype: int64

# %%
age_uni=data.age.unique()
print(age_uni)
# Out:
# [63 37 41 56 57 44 52 54 48 49 64 58 50 66 43 69 59 42 61 40 71 51 65 53
#  46 45 39 47 62 34 35 29 55 60 67 68 74 76 70 38 77]

# %%
data.cp.value_counts()
# Out:
# 0    143
# 2     87
# 1     50
# 3     23
# Name: cp, dtype: int64

# %%
data.duplicated
# Out:
# <bound method DataFrame.duplicated of      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target
# ...

# %% [markdown]
# Hence no dulplicated columns present.

# %%
#a.	Get a preliminary statistical summary of the data and explore the measures of central tendencies and spread of the data
plt.figure(figsize=(20,10))
sns.heatmap(data.corr(),annot=True)

# %%
#b.	Identify the data variables which are categorical and describe and explore these variables using the appropriate tools, such as count plot
for i in data.columns:
    print(i,len(data[i].unique()))
# Out:
# age 41
# sex 2
# cp 4
# trestbps 49
# chol 152
# fbs 2
# restecg 3
# thalach 91
# exang 2
# oldpeak 40
# slope 3
# ca 5
# thal 4
# target 2

# %% [markdown]
# From this correlation heatmap we can device that the corr between target and cp ,target and thalach,slope and thalach,target and slope is positive.
# And negative corr between thalach and age, exang and cp, exang and thalach, slope and oldpeak.

# %%
#b.	Identify the data variables which are categorical and describe and explore these variables using the appropriate tools, such as count plot
data.hist(figsize=(10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f25fed77cd0>,
# ...
#       dtype=object)

# %% [markdown]
# This counts the number of observations in each column.Also we get to know which ones are categorical and which ones are continuous.Here we can see fbs,restecg,slope,sex,cp,target,thal,ca are categorical.

# %%
#Plotting graphs between the positively correlated features
print(sns.countplot(data=data,x='cp',hue='target'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
print(sns.countplot(data=data, x='thal', hue='target'))
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
sns.countplot(data=data, x='fbs', hue='target')

# %%
print(sns.countplot(data=data, x='ca', hue='target')),
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# (None,)

# %%
print(sns.countplot(data=data, x='sex', hue='target')),
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# (None,)

# %%
print(sns.countplot(data=data, x='restecg', hue='target')),
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# (None,)

# %%
print(sns.countplot(data=data, x='slope', hue='target')),
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)
# (None,)

# %%
sns.set(rc={"figure.figsize":(20, 4)})
sns.countplot(data=data,x='age',hue='target')

# %%
prin=data[data.target==1]
prin
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 160   56    1   1       120   240    0        1      169      0      0.0
# 161   55    0   1       132   342    0        1      166      0      1.2
# 162   41    1   1       120   157    0        1      182      0      0.0
# 163   38    1   2       138   175    0        1      173      0      0.0
# 164   38    1   2       138   175    0        1      173      0      0.0
#
#      slope  ca  thal  target
# 0        0   0     1       1
# 1        0   0     2       1
# ...

# %% [markdown]
# As per the above graph '1' i.e men are more likely to be affected by CVD.

# %%
df = pd.DataFrame(data, columns = ['age'])
df
# Out:
#      age
# 0     63
# 1     37
# 2     41
# 3     56
# 4     57
# ..   ...
# 298   57
# 299   45
# 300   68
# 301   57
# 302   57
#
# [303 rows x 1 columns]

# %%
# in ascending order
df.sort_values(by='age')
# Out:
#      age
# 72    29
# 58    34
# 125   34
# 239   35
# 65    35
# ..   ...
# 60    71
# 151   71
# 129   74
# 144   76
# 238   77
#
# [303 rows x 1 columns]

# %%
    age_grp = []
    for x in df['age']:
        if 28<x<40 :    age_grp.append('middle age')
        elif 40<x<60:   age_grp.append('40 to 60 of age')

        else:           age_grp.append('above 60')

# %%
df['age_grp']=age_grp
df
# Out:
#      age          age_grp
# 0     63         above 60
# 1     37       middle age
# 2     41  40 to 60 of age
# 3     56  40 to 60 of age
# 4     57  40 to 60 of age
# ..   ...              ...
# 298   57  40 to 60 of age
# 299   45  40 to 60 of age
# 300   68         above 60
# 301   57  40 to 60 of age
# 302   57  40 to 60 of age
#
# [303 rows x 2 columns]

# %%
df
# Out:
#      age          age_grp
# 0     63         above 60
# 1     37       middle age
# 2     41  40 to 60 of age
# 3     56  40 to 60 of age
# 4     57  40 to 60 of age
# ..   ...              ...
# 298   57  40 to 60 of age
# 299   45  40 to 60 of age
# 300   68         above 60
# 301   57  40 to 60 of age
# 302   57  40 to 60 of age
#
# [303 rows x 2 columns]

# %%
d_fr=pd.concat([data,df],axis=1)
d_fr
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   3       145   233    1        0      150      0      2.3
# 1     37    1   2       130   250    0        1      187      0      3.5
# 2     41    0   1       130   204    0        0      172      0      1.4
# 3     56    1   1       120   236    0        1      178      0      0.8
# 4     57    0   0       120   354    0        1      163      1      0.6
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   57    0   0       140   241    0        1      123      1      0.2
# 299   45    1   3       110   264    0        1      132      0      1.2
# 300   68    1   0       144   193    1        1      141      0      3.4
# 301   57    1   0       130   131    0        1      115      1      1.2
# 302   57    0   1       130   236    0        0      174      0      0.0
#
#      slope  ca  thal  target  age          age_grp
# ...

# %%
#c.	Study the occurrence of CVD across the Age category
sns.countplot(data=d_fr,x='age_grp', hue='target')

# %% [markdown]
# CVD is very common in the seniors which is composed of age group 60 and above and common among adults which belong to the age group of 40 to 60. But it’s rare among the age group of 19 to 40 and very rare among the age group of 0 to 18.

# %%
data.sex.value_counts()
# Out:
# 1    207
# 0     96
# Name: sex, dtype: int64

# %% [markdown]
# From the above graph we can see that the age group of 40-60 are more likely to suffer from cardiovascular disease.

# %%
#d.	Study the composition of all patients with respect to the Sex category
sns.countplot(data=d_fr,x='sex', hue='target')
plt.title('Gender v/s target\n')
# Out:
# Text(0.5, 1.0, 'Gender v/s target\n')

# %% [markdown]
# Above graph tells that males are more susceptible to get Heart Disease than females.

# %%
#e.	Study if one can detect heart attacks based on anomalies in the resting blood pressure (trestbps) of a patient
d_fr.trestbps.unique()
# Out:
# array([145, 130, 120, 140, 172, 150, 110, 135, 160, 105, 125, 142, 155,
#        104, 138, 128, 108, 134, 122, 115, 118, 100, 124,  94, 112, 102,
#        152, 101, 132, 148, 178, 129, 180, 136, 126, 106, 156, 170, 146,
#        117, 200, 165, 174, 192, 144, 123, 154, 114, 164])

# %%
sns.set(rc={"figure.figsize":(30, 6)})
sns.countplot(data=d_fr,x='trestbps', hue='target')

# %% [markdown]
# From the above graph its is clear that heart attack connot be detected based on anomalises in the resting blood pressure as there's no certain range within which the CVD can be seen to be present.

# %%
data.chol.unique()
# Out:
# array([233, 250, 204, 236, 354, 192, 294, 263, 199, 168, 239, 275, 266,
#        211, 283, 219, 340, 226, 247, 234, 243, 302, 212, 175, 417, 197,
#        198, 177, 273, 213, 304, 232, 269, 360, 308, 245, 208, 264, 321,
#        325, 235, 257, 216, 256, 231, 141, 252, 201, 222, 260, 182, 303,
#        265, 309, 186, 203, 183, 220, 209, 258, 227, 261, 221, 205, 240,
#        318, 298, 564, 277, 214, 248, 255, 207, 223, 288, 160, 394, 315,
#        246, 244, 270, 195, 196, 254, 126, 313, 262, 215, 193, 271, 268,
#        267, 210, 295, 306, 178, 242, 180, 228, 149, 278, 253, 342, 157,
#        286, 229, 284, 224, 206, 167, 230, 335, 276, 353, 225, 330, 290,
#        172, 305, 188, 282, 185, 326, 274, 164, 307, 249, 341, 407, 217,
#        174, 281, 289, 322, 299, 300, 293, 184, 409, 259, 200, 327, 237,
#        218, 319, 166, 311, 169, 187, 176, 241, 131])

# %%
data.chol.size
# Out:
# 303

# %%
#f.	Describe the relationship between cholesterol levels and a target variable
plt.figure(figsize=(16,7))
sns.distplot(data[data['target']==0]['chol'],kde=False,bins=40)
plt.title('Chol of Heart Diseased Patients\n')
# Out:
# /usr/local/lib/python3.8/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# Text(0.5, 1.0, 'Chol of Heart Diseased Patients\n')

# %%
#g.	State what relationship exists between peak exercising and the occurrence of a heart attack
sns.countplot(data=d_fr, x='slope', hue='target')

# %%
data.thal.value_counts()
# Out:
# 2    166
# 3    117
# 1     18
# 0      2
# Name: thal, dtype: int64

# %% [markdown]
# ST segments should neither have much elevation or a downward slope ideally it should have a little elevation which is very healthy. From the graph above it is clear that as and when the slope increases the chances of the person to be having CVD increases.

# %%
#h.	Check if thalassemia is a major cause of CVD
sns.countplot(data=d_fr, x='thal', hue='target')

# %% [markdown]
# 1=normal thalassemia
# 2=fixed defect
# 3=reversible defect

# %%
#i.	List how the other factors determine the occurrence of CVD
print('Age vs trestbps(Heart Diseased Patinets)')
sns.jointplot(data=data,
              x='age',
              y='trestbps',
              kind='hex',
              cmap='Reds')
# Out:
# Age vs trestbps(Heart Diseased Patinets)

# %%
sns.jointplot(data=data,
              x='chol',
              y='age',
              kind='kde',
              cmap='PuBu'
              )

# %% [markdown]
#  As observed from the above plot we can see that most of the Heart diseased patients in their age of upper 50s or lower 60s tend to have Cholesterol between 200mg/dl to 300mg/dl.

# %%
#j.	Use a pair plot to understand the relationship between all the given variables
sns.pairplot(data,hue='target')

# %%
#3.	Build a baseline model to predict the risk of a heart attack using a logistic regression and random forest
#and explore the results while using correlation analysis and logistic regression
#(leveraging standard error and p-values from statsmodels) for feature selection

# %%
import statsmodels.api as sm
logit_model=sm.Logit(y_train,X_train)
result=logit_model.fit()
print(result.summary())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.356417
#          Iterations 7
#                            Logit Regression Results
# ...
# Dep. Variable:                 target   No. Observations:                  242
# Model:                          Logit   Df Residuals:                      229
# Method:                           MLE   Df Model:                           12
# Date:                Wed, 01 Feb 2023   Pseudo R-squ.:                  0.4832
# Time:                        17:39:54   Log-Likelihood:                -86.253
# converged:                       True   LL-Null:                       -166.91
# Covariance Type:            nonrobust   LLR p-value:                 2.824e-28
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# age            0.9464      1.033      0.916      0.359      -1.078       2.971
# ...

# %% [markdown]
# thalach,age,cp and slope being the best feature among all that have the best relationship to the performance variable.

# %%
#LOGESTIC REGRESSION
X=data.drop('target',axis=1)
y=data['target']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
X_train=(X_train-np.min(X_train))/(np.max(X_train)-
np.min(X_train)).values
X_test=(X_test-np.min(X_test))/(np.max(X_test)-np.min(X_test)).values

# %%
from sklearn.linear_model import LogisticRegression
logre = LogisticRegression()
logre.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=logre.predict(X_test)

# %%
import sklearn.metrics as metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[21,  6],
#        [ 3, 31]])

# %%
metrics.accuracy_score(y_test,y_pred)
# Out:
# 0.8524590163934426

# %% [markdown]
# The accuracy of our algorithm is 85%. this says that out of 100% of our patients 85% of them are classified correctly.

# %%
#RANDOM FOREST
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier()
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_predict=model.predict(X_test)
acc=accuracy_score(y_predict,y_test)
acc
# Out:
# 0.8360655737704918

# %% [markdown]
# Random forest is an ensamble of decision tree and is usually more accurate but in this case we can clearly see that the log regression model worked better

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.78      0.82        27
#            1       0.84      0.91      0.87        34
#
#     accuracy                           0.85        61
#    macro avg       0.86      0.84      0.85        61
# weighted avg       0.85      0.85      0.85        61

# %% [markdown]
# The classification report of the model shows that 84% prediction of absence of heart disease was predicted correct and 88% of presence of heart disease was predicted correct.

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,y_pred))
sns.heatmap(confusion_matrix(y_test,y_pred),annot=True)
# Out:
# [[21  6]
#  [ 3 31]]

# %% [markdown]
# The Confusion Matrix True Positive value is 21 and true Negative was 31 . And the False Positive came out to be 6 and False Negative is 3.

# %%
from sklearn.metrics import roc_curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred)
plt.plot(fpr,tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Heart disease classifier')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

# %%
sklearn.metrics.roc_auc_score(y_test,y_pred)
# Out:
# 0.8447712418300652

# %% [markdown]
# The accuracy here is is considerable.
