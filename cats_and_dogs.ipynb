# %% [markdown]
# <a href="https://colab.research.google.com/github/Aryamahatme/Data_sci_repo/blob/main/cats_and_dogs.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Pet Classification Model Using CNN.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import os
import tensorflow as tf
from tensorflow import keras
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras import models, layers

import warnings
warnings.filterwarnings('ignore')

# %%
dataflow = ImageDataGenerator(rescale = 1.0 / 255.0 )

# %%
train = dataflow.flow_from_directory(r'/content/train', class_mode = 'categorical')
test = dataflow.flow_from_directory(r'/content/test', class_mode = 'categorical')
# Out:
# Found 40 images belonging to 2 classes.
# Found 20 images belonging to 2 classes.

# %%
#build model according to
#Input layer ● Convolutional layer 1 with 32 filters of kernel size[5,5]
#Pooling layer 1 with pool size[2,2] and stride
#Convolutional layer 2 with 64 filters of kernel size[5,5]
#Pooling layer 2 with pool size[2,2] and stride 2
#Dense layer whose output size is fixed in the hyper parameter: fc_size=32
#Dropout layer with dropout probability 0.4
#Predict the class by doing a softmax on the output of the dropout layers.

# %%
model = models.Sequential()
model.add( layers.Conv2D( 32, (5, 5 ), activation = 'relu', padding = 'same', input_shape = (256,  256 , 3 )))
model.add(layers.MaxPooling2D(2,2))
model.add(layers.Conv2D(64, (5, 5 ), activation = 'relu'))
model.add(layers.MaxPooling2D((2,2)))
model.add(layers.Dropout(0.4))
model.add(layers.Flatten())
model.add(layers.Dense(32, activation = 'relu'))
model.add(layers.Dense(2, activation = 'softmax'))

# %%
import cv2
test_img=cv2.imread('/content/train/cat train/2.jpg')

# %%
plt.imshow(test_img)

# %%
sgd_opt =tf.keras.optimizers.SGD(lr=0.001)
# Out:
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.SGD.

# %%
#compiling model
history=model.compile( optimizer = sgd_opt, loss = 'binary_crossentropy', metrics =  ['accuracy'])

# %%
#model train for 100 epochs
history =model.fit(train, validation_data = test, epochs =100)
test_loss,test_accuracy = model.evaluate(test)
test_loss
# Out:
# Epoch 1/100
# 2/2 [==============================] - 12s 8s/step - loss: 0.7336 - accuracy: 0.4250 - val_loss: 0.6957 - val_accuracy: 0.5000
# Epoch 2/100
# 2/2 [==============================] - 11s 3s/step - loss: 0.6921 - accuracy: 0.5250 - val_loss: 0.6938 - val_accuracy: 0.5000
# Epoch 3/100
# 1/2 [==============>...............] - ETA: 1s - loss: 0.6830 - accuracy: 0.5000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-14-7028bc3cde18> in <cell line: 2>()
#       1 #model train for 100 epochs
# ----> 2 history =model.fit(train, validation_data = test, epochs =100)
#       3 test_loss,test_accuracy = model.evaluate(test)
#       4 test_loss
#
# /usr/local/lib/python3.10/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      63         filtered_tb = None
#      64         try:
# ---> 65             return fn(*args, **kwargs)
# ...

# %%
from matplotlib import pyplot as plt

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc = 'upper right')
plt.show()

# %%
#for 200 epochs
history =model.fit(train, validation_data = test, epochs =200)
test_loss, test_accuracy = model.evaluate(test)
test_loss
# Out:
# Epoch 1/200
# 2/2 [==============================] - 12s 10s/step - loss: 0.6793 - accuracy: 0.7500 - val_loss: 0.6959 - val_accuracy: 0.4500
# Epoch 2/200
# 2/2 [==============================] - 11s 9s/step - loss: 0.6851 - accuracy: 0.5250 - val_loss: 0.6955 - val_accuracy: 0.5000
# Epoch 3/200
# 2/2 [==============================] - 9s 3s/step - loss: 0.6774 - accuracy: 0.7500 - val_loss: 0.6969 - val_accuracy: 0.5000
# Epoch 4/200
# 2/2 [==============================] - 11s 3s/step - loss: 0.6757 - accuracy: 0.5750 - val_loss: 0.7096 - val_accuracy: 0.5000
# Epoch 5/200
# 2/2 [==============================] - 13s 10s/step - loss: 0.7129 - accuracy: 0.4500 - val_loss: 0.6985 - val_accuracy: 0.5000
# Epoch 6/200
# 2/2 [==============================] - 12s 5s/step - loss: 0.6644 - accuracy: 0.5750 - val_loss: 0.6957 - val_accuracy: 0.4000
# Epoch 7/200
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

# %%
#FOR 300 epochs
history=model.fit(train,validation_data=test,epochs=300)
test_loss, test_accuracy = model.evaluate(test)
test_loss
# Out:
# Epoch 1/300
# 2/2 [==============================] - 12s 10s/step - loss: 0.0039 - accuracy: 1.0000 - val_loss: 1.6405 - val_accuracy: 0.5000
# Epoch 2/300
# 2/2 [==============================] - 9s 7s/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 1.6353 - val_accuracy: 0.5000
# Epoch 3/300
# 2/2 [==============================] - 11s 4s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6421 - val_accuracy: 0.5000
# Epoch 4/300
# 2/2 [==============================] - 11s 9s/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 1.6601 - val_accuracy: 0.5500
# Epoch 5/300
# 2/2 [==============================] - 11s 9s/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.6633 - val_accuracy: 0.5000
# Epoch 6/300
# 2/2 [==============================] - 10s 3s/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 1.6743 - val_accuracy: 0.5500
# Epoch 7/300
# ...

# %%
from matplotlib import pyplot as plt
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epochs')
plt.legend(['train', 'test'], loc = 'upper left')
plt.show()

# %%
Begin by creating the ipynb file in the same parent folder where the downloaded data set is kept. The CNN model should have the following layers:
● Input layer
● Convolutional layer 1 with 32 filters of kernel size[5,5]
● Pooling layer 1 with pool size[2,2] and stride 2
● Convolutional layer 2 with 64 filters of kernel size[5,5]
● Pooling layer 2 with pool size[2,2] and stride 2
● Dense layer whose output size is fixed in the hyper parameter: fc_size=32
● Dropout layer with dropout probability 0.4
Predict the class by doing a softmax on the output of the dropout layers.
This should be followed by training and evaluation:
● For the training step, define the loss function and minimize it
● For the evaluation step, calculate the accuracy
Run the program for 100, 200, and 300 iterations, respectively. Follow this by a report on the final accuracy and loss on the evaluation data.
